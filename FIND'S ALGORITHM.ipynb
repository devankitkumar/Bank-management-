# %% [markdown]
# <a href="https://colab.research.google.com/github/devankitkumar/Bank-management-/blob/main/FIND'S%20ALGORITHM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
dataset=pd.read_csv("Data.csv")

# %%
dataset
# Out:
#       time weather temperature company humiddity    wind goes
# 0  morning   sunny        warm     yes      mild  strong  yes
# 1  evening   rainy        cold      no      mild  normal   no
# 2  morning   sunny    moderate     yes    normal  normal  yes
# 3  evening   sunny        cold     yes      high  strong  yes

# %%
#making an array of all the attributes
d=np.array(dataset)[:,-1]
print("n The attributes are : ",d)
# Out:
# n The attributes are :  ['yes' 'no' 'yes' 'yes']

# %%
#segregating the target that has positive and negative examples
target=np.array(dataset)[:,:-1]
print("n The target is: ", target)
# Out:
# n The target is:  [['morning' 'sunny' 'warm' 'yes' 'mild' 'strong']
#  ['evening' 'rainy' 'cold' 'no' 'mild' 'normal']
#  ['morning' 'sunny' 'moderate' 'yes' 'normal' 'normal']
#  ['evening' 'sunny' 'cold' 'yes' 'high' 'strong']]

# %%
dataset

concept=np.array(dataset)[:,:-1]

concept

target=np.array(dataset)[:,-1]

target

for i,val in enumerate(target):
  if val=='yes':
    specif=concept[i].copy()
    break

for i,val in enumerate(concept):
  if target[i]=='yes':
    for x in range(len(specif)):
      if val[x]!=specif[x]:
        specif[x]='?'
      else:
        pass

print(specif)
# Out:
# ['?' 'sunny' '?' 'yes' '?' '?']
